# %%
# !pip install librosa soundfile numpy matplotlib pandas

import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt


from google.colab import files
upload = files.upload()


audio = "2186.wav"
y, sr = librosa.load(audio, sr=None)
print(sr)
print(len(y))

plt.figure(figsize=(15,10))
librosa.display.waveshow(y,sr=sr)
plt.xlabel("Time(s)")
plt.ylabel("Amplitude")
plt.title("MusicNet Audio Waveform")
plt.show()

D=librosa.stft(y)
S_db=librosa.amplitude_to_db(np.abs(D), ref=np.max)
plt.figure(figsize=(15,10))
librosa.display.specshow(S_db, sr=sr, x_axis="time", y_axis="hz")


from google.colab import files
csvData = files.upload()

import pandas as pd
name = "2186.csv"
a = pd.read_csv(name, sep=None, engine="python")

for index, row in a.iterrows():
    plt.hlines(
        y=librosa.midi_to_hz(row['note']),
        xmin=row['start_time']/sr,
        xmax=row['end_time']/sr
    )

plt.title("Ground Truth Notes")
plt.xlabel("Time(s)")
plt.ylabel("Frequency(Hz)")
plt.ylim(0,2000)
plt.show()

D=librosa.stft(y)
S_db=librosa.amplitude_to_db(np.abs(D), ref=np.max)
plt.figure(figsize=(15,10))



from google.colab import files
upload=files.upload()
name="Thais.wav"
y, sr = librosa.load(name, sr=None)
D=librosa.stft(y)
S_db=librosa.amplitude_to_db(np.abs(D), ref=np.max)
plt.figure(figsize=(15,10))
librosa.display.specshow(S_db, sr=sr, x_axis="time", y_axis="hz")

plt.title("Ground Truth Notes")
plt.xlabel("Time(s)")
plt.ylabel("Frequency(Hz)")
plt.ylim(0,2000)
print(sr)
plt.show()
# Out:
# ...
#      <input type="file" id="files-4cc9ef8a-3faa-4bba-b096-3523a172589d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cc9ef8a-3faa-4bba-b096-3523a172589d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
